# %% [markdown]
# <a href="https://colab.research.google.com/github/jouhaina-bennejma/ai-detector/blob/main/A*.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx as nx

# Création du graphe
G = nx.Graph()
G.add_weighted_edges_from([
    ('A', 'B', 1),
    ('A', 'C', 4),
    ('B', 'C', 2),
    ('B', 'D', 5),
    ('C', 'D', 1)
])


# Demander à l'utilisateur les points de départ et d'arrivée
start = input("Donne le point de départ : ").strip().upper()
end = input("Donne le point d'arrivée : ").strip().upper()

# Vérifier si les nœuds existent dans le graphe
if start not in G.nodes or end not in G.nodes:
    print("Erreur: Un des points n'existe pas dans le graphe.")
else:
    # Trouver le chemin et le coût minimal
    chemin = nx.shortest_path(G, source=start, target=end, weight='weight')
    cout_min = nx.shortest_path_length(G, source=start, target=end, weight='weight')

    print("➡️ Chemin le plus court:", " → ".join(chemin))
    print("💰 Coût minimal:", cout_min)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-0a25047996dc> in <cell line: 0>()
#      13
#      14 # Demander à l'utilisateur les points de départ et d'arrivée
# ---> 15 start = input("Donne le point de départ : ").strip().upper()
#      16 end = input("Donne le point d'arrivée : ").strip().upper()
#      17
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Création du graphe avec des poids
G = nx.Graph()
edges = [
    ('A', 'B', 1), ('A', 'C', 4),
    ('B', 'C', 2), ('B', 'D', 5),
    ('C', 'D', 1)
]
G.add_weighted_edges_from(edges)

# Demander à l'utilisateur les points de départ et d'arrivée
start = input("Donne le point de départ : ").strip().upper()
end = input("Donne le point d'arrivée : ").strip().upper()

# Vérifier si les nœuds existent
if start not in G.nodes or end not in G.nodes:
    print("❌ Erreur: Un des points n'existe pas dans le graphe.")
else:
    # Trouver le chemin et le coût minimal
    chemin = nx.shortest_path(G, source=start, target=end, weight='weight')
    cout_min = nx.shortest_path_length(G, source=start, target=end, weight='weight')

    print("\n➡️ Chemin le plus court:", " → ".join(chemin))
    print("💰 Coût minimal:", cout_min)

    # Dessiner le graphe
    pos = nx.spring_layout(G)  # Position des nœuds
    plt.figure(figsize=(8,6))

    # Dessiner tous les arêtes
    nx.draw(G, pos, with_labels=True, node_size=2000, node_color="lightblue", font_size=12, font_weight="bold", edge_color="gray")

    # Dessiner les poids
    labels = nx.get_edge_attributes(G, 'weight')
    nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

    # Mettre en évidence le plus court chemin
    edges_path = list(zip(chemin, chemin[1:]))  # Transformer le chemin en liste d'arêtes
    nx.draw_networkx_edges(G, pos, edgelist=edges_path, edge_color="red", width=2)

    plt.title(f"Chemin le plus court de {start} à {end}")
    plt.show()
# Out:
# Donne le point de départ : A
# Donne le point d'arrivée : D
#
# ➡️ Chemin le plus court: A → B → C → D
# 💰 Coût minimal: 4
